# %%
import torch

# %%
model = torch.hub.load('ultralytics/yolov5',model='custom', path='./yolov5signs.pt')
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# YOLOv5 🚀 2021-12-23 torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Collecting PyYAML>=5.3.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# Installing collected packages: PyYAML
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-6.0
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# Fusing layers...
# Model Summary: 290 layers, 20865057 parameters, 0 gradients
# Adding AutoShape...

# %%
import cv2

# %%
img = cv2.imread('test.jpeg')

# %%
results = model(img)

# %%
for i in results.pred:
  for x, y, w, h, conf, classes in i:
    x=int(x.item())
    y=int(y.item())
    w=int(w.item())
    h=int(h.item())
    classes=int(classes.item())

# %%
# Out:
# 1

# %%
cv2.rectangle(img, (x, y), (w, h), (255,0,0), 2)

# %%
# from google.colab.patches import cv2_imshow

# %%
cv2.putText(img,f'{results.names[classes]}',(x+w+10,y+h),0,0.3,(0,255,0))
plt.imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7FA584179A90>
# array([[[223, 169, 134],
#         [223, 169, 134],
#         [223, 169, 134],
#         ...,
#         [223, 169, 134],
#         [223, 169, 134],
#         [223, 169, 134]],
#
#        [[223, 169, 134],
#         [223, 169, 134],
#         [223, 169, 134],
#         ...,
#         [223, 169, 134],
#         [223, 169, 134],
#         [223, 169, 134]],
#
#        [[223, 169, 134],
#         [223, 169, 134],
#         [223, 169, 134],
#         ...,
#         [223, 169, 134],
#         [223, 169, 134],
#         [223, 169, 134]],
#
#        ...,
#
#        [[204, 129,  77],
#         [204, 129,  77],
#         [204, 129,  77],
#         ...,
#         [204, 129,  77],
#         [204, 129,  77],
#         [204, 129,  77]],
#
#        [[205, 129,  77],
#         [204, 129,  77],
#         [205, 129,  77],
#         ...,
#         [205, 129,  77],
#         [204, 129,  77],
#         [205, 129,  77]],
#
#        [[207, 128,  77],
#         [205, 129,  77],
#         [207, 128,  77],
#         ...,
#         [207, 128,  77],
#         [205, 129,  77],
#         [207, 128,  77]]], dtype=uint8)
